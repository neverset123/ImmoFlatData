# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
df=pd.read_csv("data/Stuttgart.csv")

# %%
print(df.size)
# Out:
# 36808

# %%
display(df)
# Out:
#             obj_regio1                 obj_heatingType  \
# 0    Baden_Württemberg                 central_heating
# 1    Baden_Württemberg  self_contained_central_heating
# 2    Baden_Württemberg                             NaN
# 3    Baden_Württemberg                 central_heating
# 4    Baden_Württemberg                 central_heating
# ..                 ...                             ...
# 423  Baden_Württemberg  self_contained_central_heating
# 424  Baden_Württemberg                  no_information
# 425  Baden_Württemberg                             NaN
# 426  Baden_Württemberg                     gas_heating
# 427  Baden_Württemberg  self_contained_central_heating
#
#                                                                                                                                                                    obj_telekomInternetUrlAddition  \
# ...

# %%
df[["obj_scoutId"]]
# Out:
#      obj_scoutId
# 0      158051871
# 1      158052603
# 2      158047531
# 3      158045539
# 4      158048517
# ..           ...
# 423    157483639
# 424    157484170
# 425    157508652
# 426    157457399
# 427    157493729
#
# [428 rows x 1 columns]

# %%
df["obj_rentSubsidy"].dtype
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['obj_regio1', 'obj_heatingType', 'obj_telekomInternetUrlAddition',
#        'obj_cId', 'obj_newlyConst', 'obj_balcony', 'obj_picture',
#        'obj_picturecount', 'obj_usableArea', 'obj_yearConstructed', 'geo_ot',
#        'obj_privateOffer', 'obj_scoutId', 'obj_firingTypes', 'obj_hasKitchen',
#        'obj_ExclusiveExpose', 'obj_courtage', 'geo_bln', 'obj_cellar',
#        'obj_purchasePriceRange', 'obj_yearConstructedRange',
#        'obj_telekomInternetUrlBase', 'obj_houseNumber', 'obj_energyType',
#        'obj_livingSpace', 'geo_krs', 'obj_zipCode', 'obj_condition',
#        'obj_interiorQual', 'obj_highDemand', 'obj_energyEfficiencyClass',
#        'ga_cd_cxp_historicallisting', 'obj_parkingSpace', 'obj_street',
#        'obj_lift', 'obj_commissionsettings', 'obj_streetPlain',
#        'obj_typeOfFlat', 'geo_plz', 'obj_noRooms', 'obj_thermalChar',
#        'obj_assistedLiving', 'obj_lastRefurbish', 'obj_groupnumber',
# ...

# %%
df["obj_typeOfFlat"]
# Out:
# 0              roof_storey
# 1                apartment
# 2                apartment
# 3                apartment
# 4               maisonette
#               ...
# 423              apartment
# 424              apartment
# 425          terraced_flat
# 426    raised_ground_floor
# 427              apartment
# Name: obj_typeOfFlat, Length: 428, dtype: object

# %%
import pandas as pd
df_matched = pd.read_parquet("./test.parquet")

# %%
df_matched
# Out:
#    obj_scoutId                                              title  \
# 0    151257552                            Über den Wolken wohnen!
# 1    158039894        Hochwertige Gartenwohnung in perfekter Lage
# 2    158027689  Komfortable Maisonette Wohnung in bevorzugter ...
# 3    158049299  3-Zimmer-Dachgeschosswohnung mit tollem Blick ...
# 4    157982979  Wohninvestment in bester Lage: Charmante 2-Zim...
#
#    obj_purchasePrice                                        description  \
# 0             253000  Wer eine stadtnahe Wohnung sucht, die gut an d...
# 1             699900  Diese exklusive 3,5-Zimmer-Erdgeschosswohnung ...
# 2             695000  Zum Verkauf steht eine gemütliche Maisonette-W...
# 3             300000  Im 2. Stock liegt diese charmante, gepflegte D...
# 4             265000  Diese stilvolle 2-Zimmer-Wohnung im Souterrain...
#
#    obj_immotype  obj_privateOffer                   online_since  \
# 0  wohnung_kauf             False  2025-03-19T19:14:33.000+01:00
# ...

# %%
df_matched.dtypes
# Out:
# obj_scoutId                   int64
# title                        object
# obj_purchasePrice             int64
# description                  object
# obj_immotype                 object
# obj_privateOffer               bool
# online_since                 object
# obj_energyType               object
# obj_firingTypes              object
# obj_telekomInternetSpeed     object
# obj_rented                   object
# url                          object
# geo_bg                       object
# obj_usableArea              float64
# obj_yearConstructed           int64
# vector                       object
# _distance                   float32
# dtype: object
